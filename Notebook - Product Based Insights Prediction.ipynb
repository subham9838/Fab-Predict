# %% [markdown]
# # Part 1: Ingest data into a Microsoft Fabric lakehouse using Notebook

# %%
import numpy as np
import pandas as pd

# Set the number of rows
num_rows = 50000

# Define product-to-category mapping and ensure each product has a unique Product_ID
product_category_mapping = {
    'Laptop': ('Electronics', 2000),
    'Keyboard': ('Electronics', 2001),
    'Mouse': ('Electronics', 2002),
    'Mobile': ('Electronics', 2003),
    'Microwave': ('Electronics', 2004),
    'Refrigerator': ('Electronics', 2005),
    'AC': ('Electronics', 2006),
    'T-shirt': ('Clothing', 2007),
    'Bread': ('Groceries', 2008),
    'Smartphone': ('Electronics', 2009),
    'Sofa': ('Furniture', 2010),
    'Ottoman': ('Furniture', 2011),
    'Chair': ('Furniture', 2012),
    'Bed': ('Furniture', 2013),
    'Cabinet': ('Furniture', 2014),
    'Bookcase': ('Furniture', 2015),
    'Shelving': ('Furniture', 2016),
    'Armoire': ('Furniture', 2017),
    'Jacket': ('Clothing', 2018),
    'Apple': ('Groceries', 2019),
    'Berry': ('Groceries', 2020),
    'Avocado': ('Groceries', 2021),
    'Butter': ('Groceries', 2022),
    'Condiment': ('Groceries', 2023),
    'Cakes': ('Groceries', 2024),
    'Granola': ('Groceries', 2025),
    'Orange': ('Groceries', 2026),
    'Banana': ('Groceries', 2027),
    'Milk': ('Groceries', 2028),
    'Egg': ('Groceries', 2029),
    'Headphones': ('Electronics', 2030),
    'Speaker': ('Electronics', 2031),
    'Washing Machine': ('Electronics', 2032),
    'Radio': ('Electronics', 2033),
    'Printers': ('Electronics', 2034),
    'Bluetooth devices': ('Electronics', 2035),
    'Television': ('Electronics', 2036),
    'Table': ('Furniture', 2037),
    'Jeans': ('Clothing', 2038),
    'Shirt': ('Clothing', 2039),
    'Sweater': ('Clothing', 2040),
    'Socks': ('Clothing', 2041),
    'Cardigan': ('Clothing', 2042),
    'Gloves': ('Clothing', 2043),
    'Boot': ('Clothing', 2044),
    'Blazer': ('Clothing', 2045),
    'Heels': ('Clothing', 2046),
    'Hat': ('Clothing', 2047),
    'Shoes': ('Clothing', 2048)
}

# Generate unique Order_IDs and ensure multiple records for Customer_ID and Date
order_ids = np.arange(1000, 1000 + num_rows)
np.random.shuffle(order_ids)

# Generate random addresses
def generate_random_address(num_rows):
    streets = ["Main St", "High St", "Broadway", "Maple Ave", "Oak St", "Pine St", "Cedar St"]
    cities = ["Springfield", "Riverside", "Greenville", "Fairview", "Madison"]
    states = ["CA", "NY", "TX", "FL", "IL"]
    addresses = [f"{np.random.randint(1, 9999)} {np.random.choice(streets)}, {np.random.choice(cities)}, {np.random.choice(states)}" for _ in range(num_rows)]
    return addresses, [np.random.choice(cities) for _ in range(num_rows)], [np.random.choice(states) for _ in range(num_rows)], [str(np.random.randint(10000, 99999)) for _ in range(num_rows)]

addresses, cities, states, zips = generate_random_address(num_rows)

# Generate data
product_names = list(product_category_mapping.keys())
customer_ids = np.random.randint(3000, 4000, size=num_rows)
dates = pd.date_range(start='2021-01-01', end='2023-12-31', periods=num_rows)

data_amazon = {
    'Order_ID': order_ids,
    'Date': np.random.choice(dates, size=num_rows),
    'Customer_ID': np.random.choice(customer_ids, size=num_rows),
    'Product_Name': np.random.choice(product_names, size=num_rows),
    'Quantity': np.random.randint(1, 21, size=num_rows),
    'Price': np.round(np.random.uniform(1.99, 999.99, size=num_rows), 2),
    'Payment_Method': np.random.choice(['Credit Card', 'Cash', 'Debit Card', 'Mobile Payment'], size=num_rows),
    'Order_Status': np.random.choice(['Shipped', 'Pending', 'Delivered', 'Cancelled'], size=num_rows),
    'Review_Rating': np.random.randint(1, 6, size=num_rows)
}

# Create DataFrame
df_amazon = pd.DataFrame(data_amazon)

# Map product names to categories and unique Product_IDs
df_amazon['Product_Category'] = df_amazon['Product_Name'].map(lambda x: product_category_mapping[x][0])
df_amazon['Product_ID'] = df_amazon['Product_Name'].map(lambda x: product_category_mapping[x][1])

# Generate consistent customer details including address
unique_customer_ids = np.unique(customer_ids)
streets = ["Main St", "High St", "Broadway", "Maple Ave", "Oak St", "Pine St", "Cedar St"]
cities = ["Springfield", "Riverside", "Greenville", "Fairview", "Madison"]
states = ["CA", "NY", "TX", "FL", "IL"]

customer_details = {
    'Customer_ID': unique_customer_ids,
    'Gender': np.random.choice(['Male', 'Female', 'Other'], size=len(unique_customer_ids)),
    'Age': np.random.randint(18, 80, size=len(unique_customer_ids)),
    'Customer_Type': np.random.choice(['Gold', 'Silver', 'Bronze'], size=len(unique_customer_ids)),
    'Shipping_Address': [f"{np.random.randint(1, 9999)} {np.random.choice(streets)}, {np.random.choice(cities)}, {np.random.choice(states)}" for _ in range(len(unique_customer_ids))],
    'City': [np.random.choice(cities) for _ in range(len(unique_customer_ids))],
    'State': [np.random.choice(states) for _ in range(len(unique_customer_ids))],
    'Country': ['United States'] * len(unique_customer_ids),
    'Zipcode': [str(np.random.randint(10000, 99999)) for _ in range(len(unique_customer_ids))]
}

# Create DataFrame for customer details
df_customer_details = pd.DataFrame(customer_details)

# Merge customer details into the main dataset
df_amazon = pd.merge(df_amazon, df_customer_details, on='Customer_ID', how='left')

# Calculate Total_Amount
df_amazon['Total_Amount'] = np.round(df_amazon['Quantity'] * df_amazon['Price'], 2)

# Save to CSV
file_path_amazon_updated_complete = 'amazon_data_updated_complete.csv'
df_amazon.to_csv(file_path_amazon_updated_complete, index=False)

# Download the CSV file (works in Jupyter Notebooks)
from IPython.display import FileLink
FileLink(file_path_amazon_updated_complete)
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 16, Finished, Available, Finished)
# /mnt/var/hadoop/tmp/nm-secondary-local-dir/usercache/trusted-service-user/appcache/application_1720090718213_0001/container_1720090718213_0001_01_000001/amazon_data_updated_complete.csv

# %% [markdown]
# ##### Read data from a CSV file

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Read CSV from Lakehouse") \
    .getOrCreate()
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 17, Finished, Available, Finished)

# %% [markdown]
# ##### Load and Prepare the Data

# %%
lakehouse_path = "Files/Bronze/FabPredictRetail_Final.csv"

df = spark.read.csv(lakehouse_path, header=True, inferSchema=True)
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 18, Finished, Available, Finished)

# %% [markdown]
# ##### Converts a Spark DataFrame (df) into a Pandas DataFrame.

# %%
df = df.toPandas()
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 19, Finished, Available, Finished)

# %% [markdown]
# ##### Display the table

# %%
display(df);
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 20, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, efcd64c0-5a46-4178-897b-9825f4d08d54)

# %% [markdown]
# # Part 2: Explore and clean data using Microsoft Fabric notebooks

# %%
# Define a new function that include all above Data Wrangler operations
def clean_data(df):
    # Drop rows with missing data across all columns
    df.dropna(inplace=True)

df_clean = clean_data(df.copy())
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 22, Finished, Available, Finished)

# %% [markdown]
# # Part 3: Train and register a machine learning model (Prophet Model)

# %%
pip install prophet
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 23, Finished, Available, Finished)
# Requirement already satisfied: prophet in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prophet) (1.2.4)
# Requirement already satisfied: numpy>=1.15.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prophet) (1.24.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prophet) (3.7.2)
# Requirement already satisfied: pandas>=1.0.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prophet) (2.0.3)
# Requirement already satisfied: holidays>=0.25 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prophet) (0.35)
# Requirement already satisfied: tqdm>=4.36.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prophet) (4.66.1)
# Requirement already satisfied: importlib-resources in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prophet) (6.1.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.0)
# Requirement already satisfied: python-dateutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
import seaborn as sns

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Extract the Year and Quarter from the Date
df['Year'] = df['Date'].dt.year
df['Quarter'] = df['Date'].dt.to_period('Q').astype(str)

# Filter data for analysis
analysis_data = df.copy()
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 24, Finished, Available, Finished)

# %%
# Aggregate sales data by year, category, and product
category_sales_yearly = df.groupby(['Year', 'Product_Category']).agg({'Quantity': 'sum'}).reset_index()
product_sales_yearly = df.groupby(['Year', 'Product_Name']).agg({'Quantity': 'sum'}).reset_index()
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 25, Finished, Available, Finished)

# %%
# Prepare the data for Prophet for categories
category_forecast_data = {}
for category in category_sales_yearly['Product_Category'].unique():
    category_data = category_sales_yearly[category_sales_yearly['Product_Category'] == category][['Year', 'Quantity']]
    category_data.columns = ['ds', 'y']
    category_data['ds'] = category_data['ds'].astype(str) + '-01-01'
    category_forecast_data[category] = category_data

# Prepare the data for Prophet for products
product_forecast_data = {}
for product in product_sales_yearly['Product_Name'].unique():
    product_data = product_sales_yearly[product_sales_yearly['Product_Name'] == product][['Year', 'Quantity']]
    product_data.columns = ['ds', 'y']
    product_data['ds'] = product_data['ds'].astype(str) + '-01-01'
    product_forecast_data[product] = product_data

# Initialize dictionaries to store forecasts
category_forecasts = {}
product_forecasts = {}

# Forecasting for categories
for category, data in category_forecast_data.items():
    model = Prophet()
    model.fit(data)
    
    # Create a dataframe for future dates (next year)
    future = model.make_future_dataframe(periods=1, freq='Y')
    
    # Forecast future sales
    forecast = model.predict(future)
    
    # Store the forecasted sales
    forecast.rename(columns={'yhat': 'Quantity'}, inplace=True)
    category_forecasts[category] = forecast[['ds', 'Quantity']]

# Forecasting for products
for product, data in product_forecast_data.items():
    model = Prophet()
    model.fit(data)
    
    # Create a dataframe for future dates (next year)
    future = model.make_future_dataframe(periods=1, freq='Y')
    
    # Forecast future sales
    forecast = model.predict(future)
    
    # Store the forecasted sales
    forecast.rename(columns={'yhat': 'Quantity'}, inplace=True)
    product_forecasts[product] = forecast[['ds', 'Quantity']]

# Combine all forecasts into a single dataframe
all_category_forecasts = pd.concat(category_forecasts.values(), keys=category_forecasts.keys(), names=['Product_Category', 'Index'])
all_category_forecasts.reset_index(level=1, drop=True, inplace=True)
all_category_forecasts.reset_index(inplace=True)

all_product_forecasts = pd.concat(product_forecasts.values(), keys=product_forecasts.keys(), names=['Product_Name', 'Index'])
all_product_forecasts.reset_index(level=1, drop=True, inplace=True)
all_product_forecasts.reset_index(inplace=True)
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 26, Finished, Available, Finished)
# 11:19:14 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:17 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:20 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:20 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:23 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:23 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:26 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:26 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:30 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:30 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:33 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:33 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:33 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:36 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:39 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:42 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:45 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:46 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:46 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:49 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:49 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:52 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:52 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:52 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:52 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:55 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:55 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:55 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:55 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:59 - cmdstanpy - INFO - Chain [1] done processing
# 11:19:59 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:02 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:02 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:05 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:08 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:08 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:11 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:11 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:14 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:14 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:17 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:17 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:17 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:21 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:21 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:21 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:21 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:21 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:21 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:24 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:24 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:27 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:27 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:30 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:30 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:33 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:33 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:36 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:36 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:36 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:40 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:40 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:40 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:40 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:40 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:40 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:40 - cmdstanpy - INFO - Chain [1] done processing
# 11:20:40 - cmdstanpy - INFO - Chain [1] start processing
# 11:20:40 - cmdstanpy - INFO - Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/j9b9ak34.json
# input tempfile: /tmp/tmprrcprbkx/55u0spv7.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66107', 'data', 'file=/tmp/tmprrcprbkx/j9b9ak34.json', 'init=/tmp/tmprrcprbkx/55u0spv7.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelu0xy6mud/prophet_model-20240704111914.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/jd5e8z6p.json
# input tempfile: /tmp/tmprrcprbkx/quv2m5ap.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4563', 'data', 'file=/tmp/tmprrcprbkx/jd5e8z6p.json', 'init=/tmp/tmprrcprbkx/quv2m5ap.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model9e5_nfvn/prophet_model-20240704111917.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/3_67ops_.json
# input tempfile: /tmp/tmprrcprbkx/fql1zp2v.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62824', 'data', 'file=/tmp/tmprrcprbkx/3_67ops_.json', 'init=/tmp/tmprrcprbkx/fql1zp2v.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modellvjw8sf_/prophet_model-20240704111920.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/grka9b8k.json
# input tempfile: /tmp/tmprrcprbkx/kpfnjo1_.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3049', 'data', 'file=/tmp/tmprrcprbkx/grka9b8k.json', 'init=/tmp/tmprrcprbkx/kpfnjo1_.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model2tp46pm8/prophet_model-20240704111923.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/3y6i_8de.json
# input tempfile: /tmp/tmprrcprbkx/rcbzdi9c.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7631', 'data', 'file=/tmp/tmprrcprbkx/3y6i_8de.json', 'init=/tmp/tmprrcprbkx/rcbzdi9c.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeljp34k1zc/prophet_model-20240704111926.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/st2yrx2d.json
# input tempfile: /tmp/tmprrcprbkx/qpq_g65t.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56733', 'data', 'file=/tmp/tmprrcprbkx/st2yrx2d.json', 'init=/tmp/tmprrcprbkx/qpq_g65t.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model915aw0ig/prophet_model-20240704111930.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/gv_7foof.json
# input tempfile: /tmp/tmprrcprbkx/b1x63wdb.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5655', 'data', 'file=/tmp/tmprrcprbkx/gv_7foof.json', 'init=/tmp/tmprrcprbkx/b1x63wdb.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelvbvvcl21/prophet_model-20240704111930.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/61nvudec.json
# input tempfile: /tmp/tmprrcprbkx/ci7qhhyp.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24449', 'data', 'file=/tmp/tmprrcprbkx/61nvudec.json', 'init=/tmp/tmprrcprbkx/ci7qhhyp.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeln5iurwqa/prophet_model-20240704111933.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/quplo0op.json
# input tempfile: /tmp/tmprrcprbkx/uzylllx5.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39151', 'data', 'file=/tmp/tmprrcprbkx/quplo0op.json', 'init=/tmp/tmprrcprbkx/uzylllx5.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeld06bhd05/prophet_model-20240704111933.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/hure6s5b.json
# input tempfile: /tmp/tmprrcprbkx/tbcgb0ev.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46815', 'data', 'file=/tmp/tmprrcprbkx/hure6s5b.json', 'init=/tmp/tmprrcprbkx/tbcgb0ev.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model5s8xfnrl/prophet_model-20240704111933.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/3gwn6x1m.json
# input tempfile: /tmp/tmprrcprbkx/boqnynu3.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43424', 'data', 'file=/tmp/tmprrcprbkx/3gwn6x1m.json', 'init=/tmp/tmprrcprbkx/boqnynu3.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelmpalvt4z/prophet_model-20240704111936.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/_mk7n2fi.json
# input tempfile: /tmp/tmprrcprbkx/98cimo6e.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70112', 'data', 'file=/tmp/tmprrcprbkx/_mk7n2fi.json', 'init=/tmp/tmprrcprbkx/98cimo6e.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeln7u3s993/prophet_model-20240704111939.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/6qdt63hm.json
# input tempfile: /tmp/tmprrcprbkx/voi576ay.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96008', 'data', 'file=/tmp/tmprrcprbkx/6qdt63hm.json', 'init=/tmp/tmprrcprbkx/voi576ay.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeli17n39jn/prophet_model-20240704111942.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/h830m7pn.json
# input tempfile: /tmp/tmprrcprbkx/egxx4h12.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89366', 'data', 'file=/tmp/tmprrcprbkx/h830m7pn.json', 'init=/tmp/tmprrcprbkx/egxx4h12.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelej2uem9e/prophet_model-20240704111946.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/m8lklih0.json
# input tempfile: /tmp/tmprrcprbkx/nwl5aswm.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59067', 'data', 'file=/tmp/tmprrcprbkx/m8lklih0.json', 'init=/tmp/tmprrcprbkx/nwl5aswm.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modell89v4e_3/prophet_model-20240704111946.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/27f9tpyd.json
# input tempfile: /tmp/tmprrcprbkx/116pou_a.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14274', 'data', 'file=/tmp/tmprrcprbkx/27f9tpyd.json', 'init=/tmp/tmprrcprbkx/116pou_a.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model2fwnqie4/prophet_model-20240704111946.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/nboclama.json
# input tempfile: /tmp/tmprrcprbkx/xhhej1yg.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88991', 'data', 'file=/tmp/tmprrcprbkx/nboclama.json', 'init=/tmp/tmprrcprbkx/xhhej1yg.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelxvdn_i09/prophet_model-20240704111949.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/mnk_ai7o.json
# input tempfile: /tmp/tmprrcprbkx/udz6sbsp.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79262', 'data', 'file=/tmp/tmprrcprbkx/mnk_ai7o.json', 'init=/tmp/tmprrcprbkx/udz6sbsp.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model8te3xezp/prophet_model-20240704111952.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/lo4s03pn.json
# input tempfile: /tmp/tmprrcprbkx/5caturbp.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93150', 'data', 'file=/tmp/tmprrcprbkx/lo4s03pn.json', 'init=/tmp/tmprrcprbkx/5caturbp.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelnjl1a151/prophet_model-20240704111952.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/gzrb_g2s.json
# input tempfile: /tmp/tmprrcprbkx/elg8i4kf.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24723', 'data', 'file=/tmp/tmprrcprbkx/gzrb_g2s.json', 'init=/tmp/tmprrcprbkx/elg8i4kf.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model5tgb62zj/prophet_model-20240704111955.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/t91htz9k.json
# input tempfile: /tmp/tmprrcprbkx/2ql2px1d.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37386', 'data', 'file=/tmp/tmprrcprbkx/t91htz9k.json', 'init=/tmp/tmprrcprbkx/2ql2px1d.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model8hots52l/prophet_model-20240704111955.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/x404zunh.json
# input tempfile: /tmp/tmprrcprbkx/alv90ff8.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47539', 'data', 'file=/tmp/tmprrcprbkx/x404zunh.json', 'init=/tmp/tmprrcprbkx/alv90ff8.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeli3tigcm4/prophet_model-20240704111955.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/cfgu2z7g.json
# input tempfile: /tmp/tmprrcprbkx/_50mpz72.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64081', 'data', 'file=/tmp/tmprrcprbkx/cfgu2z7g.json', 'init=/tmp/tmprrcprbkx/_50mpz72.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelqjt_lst9/prophet_model-20240704111958.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/w1msb92y.json
# input tempfile: /tmp/tmprrcprbkx/38n_pceo.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39488', 'data', 'file=/tmp/tmprrcprbkx/w1msb92y.json', 'init=/tmp/tmprrcprbkx/38n_pceo.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelu9qmtg2r/prophet_model-20240704111959.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/nyz_j13m.json
# input tempfile: /tmp/tmprrcprbkx/oxj556ys.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12584', 'data', 'file=/tmp/tmprrcprbkx/nyz_j13m.json', 'init=/tmp/tmprrcprbkx/oxj556ys.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelt6t1s1xb/prophet_model-20240704112002.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/8f31fn2_.json
# input tempfile: /tmp/tmprrcprbkx/60l45tms.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15858', 'data', 'file=/tmp/tmprrcprbkx/8f31fn2_.json', 'init=/tmp/tmprrcprbkx/60l45tms.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model39l7zulc/prophet_model-20240704112002.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/hxpqysmj.json
# input tempfile: /tmp/tmprrcprbkx/a62mokea.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37846', 'data', 'file=/tmp/tmprrcprbkx/hxpqysmj.json', 'init=/tmp/tmprrcprbkx/a62mokea.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeljedc333p/prophet_model-20240704112005.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/azl4o0vv.json
# input tempfile: /tmp/tmprrcprbkx/afer0az9.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45611', 'data', 'file=/tmp/tmprrcprbkx/azl4o0vv.json', 'init=/tmp/tmprrcprbkx/afer0az9.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeldelj1sj2/prophet_model-20240704112008.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/wudefiez.json
# input tempfile: /tmp/tmprrcprbkx/j7s3fz4n.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73374', 'data', 'file=/tmp/tmprrcprbkx/wudefiez.json', 'init=/tmp/tmprrcprbkx/j7s3fz4n.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeljft28hvp/prophet_model-20240704112011.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/8xet72ga.json
# input tempfile: /tmp/tmprrcprbkx/afnnysdj.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2510', 'data', 'file=/tmp/tmprrcprbkx/8xet72ga.json', 'init=/tmp/tmprrcprbkx/afnnysdj.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelyrqt7kzg/prophet_model-20240704112014.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/8psb7cz9.json
# input tempfile: /tmp/tmprrcprbkx/p540vwiq.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9987', 'data', 'file=/tmp/tmprrcprbkx/8psb7cz9.json', 'init=/tmp/tmprrcprbkx/p540vwiq.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelv323h3cc/prophet_model-20240704112017.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/vr9q83zt.json
# input tempfile: /tmp/tmprrcprbkx/ces7polu.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95767', 'data', 'file=/tmp/tmprrcprbkx/vr9q83zt.json', 'init=/tmp/tmprrcprbkx/ces7polu.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelrh2i14zi/prophet_model-20240704112017.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/ablyhbj5.json
# input tempfile: /tmp/tmprrcprbkx/uogqq9yk.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18700', 'data', 'file=/tmp/tmprrcprbkx/ablyhbj5.json', 'init=/tmp/tmprrcprbkx/uogqq9yk.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelmeee1yow/prophet_model-20240704112017.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/uepcfnqk.json
# input tempfile: /tmp/tmprrcprbkx/g7ns4gse.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83755', 'data', 'file=/tmp/tmprrcprbkx/uepcfnqk.json', 'init=/tmp/tmprrcprbkx/g7ns4gse.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelna35ba_x/prophet_model-20240704112021.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/xk7_0vdz.json
# input tempfile: /tmp/tmprrcprbkx/sjrxet34.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24554', 'data', 'file=/tmp/tmprrcprbkx/xk7_0vdz.json', 'init=/tmp/tmprrcprbkx/sjrxet34.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelorclezxb/prophet_model-20240704112021.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/5kvzxm2x.json
# input tempfile: /tmp/tmprrcprbkx/0vaz13ho.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12078', 'data', 'file=/tmp/tmprrcprbkx/5kvzxm2x.json', 'init=/tmp/tmprrcprbkx/0vaz13ho.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model6trni6mk/prophet_model-20240704112021.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/jl8603am.json
# input tempfile: /tmp/tmprrcprbkx/d7p4cvi8.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22303', 'data', 'file=/tmp/tmprrcprbkx/jl8603am.json', 'init=/tmp/tmprrcprbkx/d7p4cvi8.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model5sreuhfe/prophet_model-20240704112024.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/dekc4wsz.json
# input tempfile: /tmp/tmprrcprbkx/nntnsgho.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70113', 'data', 'file=/tmp/tmprrcprbkx/dekc4wsz.json', 'init=/tmp/tmprrcprbkx/nntnsgho.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelvt_iui0c/prophet_model-20240704112027.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/30uotz42.json
# input tempfile: /tmp/tmprrcprbkx/j_e55yti.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12618', 'data', 'file=/tmp/tmprrcprbkx/30uotz42.json', 'init=/tmp/tmprrcprbkx/j_e55yti.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelmdp4pna4/prophet_model-20240704112030.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/wvumn6ey.json
# input tempfile: /tmp/tmprrcprbkx/vx4c6pym.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92814', 'data', 'file=/tmp/tmprrcprbkx/wvumn6ey.json', 'init=/tmp/tmprrcprbkx/vx4c6pym.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelovuhjhl2/prophet_model-20240704112030.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/p0vsrath.json
# input tempfile: /tmp/tmprrcprbkx/gqgtots1.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27934', 'data', 'file=/tmp/tmprrcprbkx/p0vsrath.json', 'init=/tmp/tmprrcprbkx/gqgtots1.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model0x3i6pm_/prophet_model-20240704112033.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/pbr7t9i5.json
# input tempfile: /tmp/tmprrcprbkx/vnlp9gen.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8584', 'data', 'file=/tmp/tmprrcprbkx/pbr7t9i5.json', 'init=/tmp/tmprrcprbkx/vnlp9gen.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeld4n4a55q/prophet_model-20240704112036.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/kkzc1pdt.json
# input tempfile: /tmp/tmprrcprbkx/65ezujiy.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49617', 'data', 'file=/tmp/tmprrcprbkx/kkzc1pdt.json', 'init=/tmp/tmprrcprbkx/65ezujiy.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modele1kp550x/prophet_model-20240704112036.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/lydtirja.json
# input tempfile: /tmp/tmprrcprbkx/okhez4n8.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85180', 'data', 'file=/tmp/tmprrcprbkx/lydtirja.json', 'init=/tmp/tmprrcprbkx/okhez4n8.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeljrmjmvfp/prophet_model-20240704112037.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/r7id8ra2.json
# input tempfile: /tmp/tmprrcprbkx/l2s5wt64.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27919', 'data', 'file=/tmp/tmprrcprbkx/r7id8ra2.json', 'init=/tmp/tmprrcprbkx/l2s5wt64.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model23u1tcy8/prophet_model-20240704112037.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/j9tp9tyg.json
# input tempfile: /tmp/tmprrcprbkx/v7t1jxe2.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8664', 'data', 'file=/tmp/tmprrcprbkx/j9tp9tyg.json', 'init=/tmp/tmprrcprbkx/v7t1jxe2.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeld0a1hbi2/prophet_model-20240704112037.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/1xuhzk3j.json
# input tempfile: /tmp/tmprrcprbkx/vv_djj15.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64305', 'data', 'file=/tmp/tmprrcprbkx/1xuhzk3j.json', 'init=/tmp/tmprrcprbkx/vv_djj15.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_model_x7endtb/prophet_model-20240704112037.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/p94zzcjp.json
# input tempfile: /tmp/tmprrcprbkx/gqkt5az_.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47001', 'data', 'file=/tmp/tmprrcprbkx/p94zzcjp.json', 'init=/tmp/tmprrcprbkx/gqkt5az_.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelj1gmsel1/prophet_model-20240704112037.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/5s3q5vzc.json
# input tempfile: /tmp/tmprrcprbkx/r3hl5cgt.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=329', 'data', 'file=/tmp/tmprrcprbkx/5s3q5vzc.json', 'init=/tmp/tmprrcprbkx/r3hl5cgt.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelsr9gahiq/prophet_model-20240704112037.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/l5dw6f7o.json
# input tempfile: /tmp/tmprrcprbkx/49xc7evb.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9656', 'data', 'file=/tmp/tmprrcprbkx/l5dw6f7o.json', 'init=/tmp/tmprrcprbkx/49xc7evb.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelzszpr5q0/prophet_model-20240704112040.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/4cw7vn6o.json
# input tempfile: /tmp/tmprrcprbkx/77smri4w.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39500', 'data', 'file=/tmp/tmprrcprbkx/4cw7vn6o.json', 'init=/tmp/tmprrcprbkx/77smri4w.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelv8rojs46/prophet_model-20240704112040.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/vcob54_z.json
# input tempfile: /tmp/tmprrcprbkx/pk8b3hmc.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35566', 'data', 'file=/tmp/tmprrcprbkx/vcob54_z.json', 'init=/tmp/tmprrcprbkx/pk8b3hmc.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modeloeh5va5e/prophet_model-20240704112040.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing
# Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# n_changepoints greater than number of observations. Using 1.
# input tempfile: /tmp/tmprrcprbkx/5rnbcwd4.json
# input tempfile: /tmp/tmprrcprbkx/ab9a8gef.json
# idx 0
# running CmdStan, num_threads: None
# CmdStan args: ['/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69260', 'data', 'file=/tmp/tmprrcprbkx/5rnbcwd4.json', 'init=/tmp/tmprrcprbkx/ab9a8gef.json', 'output', 'file=/tmp/tmprrcprbkx/prophet_modelcm8wy5r0/prophet_model-20240704112040.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# Chain [1] start processing
# Chain [1] done processing

# %%
# Rank categories and products based on historical sales for each year
category_sales_yearly['Rank'] = category_sales_yearly.groupby('Year')['Quantity'].rank("dense", ascending=False)
product_sales_yearly['Rank'] = product_sales_yearly.groupby('Year')['Quantity'].rank("dense", ascending=False)

# Extract data for visualization
historical_category_sales_2021 = category_sales_yearly[category_sales_yearly['Year'] == 2021].sort_values(by='Rank')
historical_category_sales_2022 = category_sales_yearly[category_sales_yearly['Year'] == 2022].sort_values(by='Rank')
historical_category_sales_2023 = category_sales_yearly[category_sales_yearly['Year'] == 2023].sort_values(by='Rank')

historical_product_sales_2021 = product_sales_yearly[product_sales_yearly['Year'] == 2021].sort_values(by='Rank')
historical_product_sales_2022 = product_sales_yearly[product_sales_yearly['Year'] == 2022].sort_values(by='Rank')
historical_product_sales_2023 = product_sales_yearly[product_sales_yearly['Year'] == 2023].sort_values(by='Rank')

print("Historical Sales Ranking by Category for 2021:")
print(historical_category_sales_2021)
print("Historical Sales Ranking by Category for 2022:")
print(historical_category_sales_2022)
print("Historical Sales Ranking by Category for 2023:")
print(historical_category_sales_2023)

print("Historical Sales Ranking by Product for 2021:")
print(historical_product_sales_2021)
print("Historical Sales Ranking by Product for 2022:")
print(historical_product_sales_2022)
print("Historical Sales Ranking by Product for 2023:")
print(historical_product_sales_2023)
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 27, Finished, Available, Finished)
# Historical Sales Ranking by Category for 2021:
#    Year Product_Category  Quantity  Rank
# 1  2021      Electronics     53719   1.0
# 0  2021         Clothing     46856   2.0
# 3  2021        Groceries     43773   3.0
# 2  2021        Furniture     32689   4.0
# Historical Sales Ranking by Category for 2022:
#    Year Product_Category  Quantity  Rank
# 5  2022      Electronics     53259   1.0
# 4  2022         Clothing     45726   2.0
# 7  2022        Groceries     43372   3.0
# 6  2022        Furniture     31648   4.0
# Historical Sales Ranking by Category for 2023:
#     Year Product_Category  Quantity  Rank
# 9   2023      Electronics     53498   1.0
# 8   2023         Clothing     47890   2.0
# 11  2023        Groceries     42285   3.0
# 10  2023        Furniture     30724   4.0
# Historical Sales Ranking by Product for 2021:
#     Year       Product_Name  Quantity  Rank
# 45  2021            T-shirt      4105   1.0
# 9   2021           Bookcase      3898   2.0
# 14  2021              Cakes      3877   3.0
# 35  2021              Radio      3870   4.0
# 31  2021              Mouse      3848   5.0
# 38  2021              Shirt      3825   6.0
# 22  2021         Headphones      3800   7.0
# 15  2021           Cardigan      3794   8.0
# 10  2021               Boot      3778   9.0
# 34  2021           Printers      3777  10.0
# 41  2021              Socks      3739  11.0
# 2   2021            Armoire      3733  12.0
# 16  2021              Chair      3725  13.0
# 3   2021            Avocado      3718  14.0
# 48  2021    Washing Machine      3715  15.0
# 23  2021              Heels      3711  16.0
# 1   2021              Apple      3710  17.0
# 43  2021            Speaker      3703  18.0
# 11  2021              Bread      3697  19.0
# 4   2021             Banana      3697  19.0
# 29  2021               Milk      3692  20.0
# 20  2021            Granola      3681  21.0
# 47  2021         Television      3644  22.0
# 13  2021            Cabinet      3644  22.0
# 28  2021          Microwave      3639  23.0
# 30  2021             Mobile      3635  24.0
# 44  2021            Sweater      3615  25.0
# 5   2021                Bed      3613  26.0
# 32  2021             Orange      3610  27.0
# 12  2021             Butter      3594  28.0
# 17  2021          Condiment      3588  29.0
# 19  2021             Gloves      3586  30.0
# 26  2021           Keyboard      3585  31.0
# 46  2021              Table      3574  32.0
# 24  2021             Jacket      3555  33.0
# 37  2021           Shelving      3533  34.0
# 40  2021         Smartphone      3499  35.0
# 33  2021            Ottoman      3491  36.0
# 42  2021               Sofa      3478  37.0
# 6   2021              Berry      3462  38.0
# 18  2021                Egg      3447  39.0
# 39  2021              Shoes      3388  40.0
# 0   2021                 AC      3380  41.0
# 25  2021              Jeans      3328  42.0
# 21  2021                Hat      3324  43.0
# 36  2021       Refrigerator      3276  44.0
# 8   2021  Bluetooth devices      3268  45.0
# 7   2021             Blazer      3108  46.0
# 27  2021             Laptop      3080  47.0
# Historical Sales Ranking by Product for 2022:
#     Year       Product_Name  Quantity  Rank
# 72  2022              Heels      3919   1.0
# 50  2022              Apple      3892   2.0
# 69  2022            Granola      3888   3.0
# 71  2022         Headphones      3872   4.0
# 67  2022                Egg      3846   5.0
# 92  2022            Speaker      3846   5.0
# 62  2022            Cabinet      3770   6.0
# 79  2022             Mobile      3755   7.0
# 80  2022              Mouse      3742   8.0
# 86  2022           Shelving      3735   9.0
# 81  2022             Orange      3730  10.0
# 93  2022            Sweater      3707  11.0
# 84  2022              Radio      3688  12.0
# 64  2022           Cardigan      3677  13.0
# 97  2022    Washing Machine      3670  14.0
# 76  2022             Laptop      3669  15.0
# 52  2022            Avocado      3644  16.0
# 66  2022          Condiment      3638  17.0
# 51  2022            Armoire      3608  18.0
# 60  2022              Bread      3601  19.0
# 91  2022               Sofa      3599  20.0
# 87  2022              Shirt      3590  21.0
# 73  2022             Jacket      3584  22.0
# 63  2022              Cakes      3564  23.0
# 61  2022             Butter      3562  24.0
# 89  2022         Smartphone      3561  25.0
# 82  2022            Ottoman      3553  26.0
# 94  2022            T-shirt      3528  27.0
# 49  2022                 AC      3521  28.0
# 56  2022             Blazer      3485  29.0
# 57  2022  Bluetooth devices      3472  30.0
# 59  2022               Boot      3468  31.0
# 74  2022              Jeans      3434  32.0
# 70  2022                Hat      3420  33.0
# 58  2022           Bookcase      3397  34.0
# 53  2022             Banana      3394  35.0
# 95  2022              Table      3384  36.0
# 77  2022          Microwave      3376  37.0
# 75  2022           Keyboard      3376  37.0
# 54  2022                Bed      3367  38.0
# 68  2022             Gloves      3343  39.0
# 55  2022              Berry      3333  40.0
# 88  2022              Shoes      3302  41.0
# 78  2022               Milk      3280  42.0
# 90  2022              Socks      3269  43.0
# 85  2022       Refrigerator      3239  44.0
# 83  2022           Printers      3239  44.0
# 65  2022              Chair      3235  45.0
# 96  2022         Television      3233  46.0
# Historical Sales Ranking by Product for 2023:
#      Year       Product_Name  Quantity  Rank
# 113  2023           Cardigan      4126   1.0
# 136  2023              Shirt      4063   2.0
# 143  2023            T-shirt      3964   3.0
# 98   2023                 AC      3957   4.0
# 124  2023           Keyboard      3864   5.0
# 120  2023         Headphones      3829   6.0
# 145  2023         Television      3816   7.0
# 122  2023             Jacket      3794   8.0
# 144  2023              Table      3778   9.0
# 109  2023              Bread      3754  10.0
# 130  2023             Orange      3753  11.0
# 119  2023                Hat      3749  12.0
# 142  2023            Sweater      3725  13.0
# 121  2023              Heels      3724  14.0
# 125  2023             Laptop      3708  15.0
# 129  2023              Mouse      3698  16.0
# 133  2023              Radio      3693  17.0
# 137  2023              Shoes      3692  18.0
# 100  2023            Armoire      3674  19.0
# 107  2023           Bookcase      3658  20.0
# 102  2023             Banana      3622  21.0
# 115  2023          Condiment      3603  22.0
# 132  2023           Printers      3587  23.0
# 105  2023             Blazer      3586  24.0
# 108  2023               Boot      3564  25.0
# 99   2023              Apple      3550  26.0
# 110  2023             Butter      3544  27.0
# 116  2023                Egg      3531  28.0
# 127  2023               Milk      3528  29.0
# 104  2023              Berry      3513  30.0
# 106  2023  Bluetooth devices      3489  31.0
# 134  2023       Refrigerator      3473  32.0
# 131  2023            Ottoman      3473  32.0
# 126  2023          Microwave      3455  33.0
# 117  2023             Gloves      3447  34.0
# 118  2023            Granola      3404  35.0
# 111  2023            Cabinet      3395  36.0
# 141  2023            Speaker      3393  37.0
# 135  2023           Shelving      3370  38.0
# 123  2023              Jeans      3320  39.0
# 112  2023              Cakes      3318  40.0
# 146  2023    Washing Machine      3265  41.0
# 128  2023             Mobile      3253  42.0
# 114  2023              Chair      3222  43.0
# 101  2023            Avocado      3165  44.0
# 103  2023                Bed      3147  45.0
# 139  2023              Socks      3136  46.0
# 138  2023         Smartphone      3018  47.0
# 140  2023               Sofa      3007  48.0

# %% [markdown]
# # Part 4: Prediction of Product Category and Product Name

# %%
# Summarize forecasted sales by category and product for the next year
future_year = all_category_forecasts['ds'].dt.year.max()
future_category_sales = all_category_forecasts[all_category_forecasts['ds'].dt.year == future_year].groupby('Product_Category')['Quantity'].sum().reset_index()
future_product_sales = all_product_forecasts[all_product_forecasts['ds'].dt.year == future_year].groupby('Product_Name')['Quantity'].sum().reset_index()

# Rank categories and products based on forecasted sales
future_category_sales = future_category_sales.sort_values(by='Quantity', ascending=False)
future_category_sales['Rank'] = range(1, len(future_category_sales) + 1)

future_product_sales = future_product_sales.sort_values(by='Quantity', ascending=False)
future_product_sales['Rank'] = range(1, len(future_product_sales) + 1)

print("Forecasted Sales Ranking by Category for Next Year:")
print(future_category_sales)
print("Forecasted Sales Ranking by Product for Next Year:")
print(future_product_sales)
# Out:
# StatementMeta(, fdf6cec7-99c7-4b1e-9a19-bbd37f559453, 28, Finished, Available, Finished)
# Forecasted Sales Ranking by Category for Next Year:
#   Product_Category       Quantity  Rank
# 1      Electronics  116601.447794     1
# 0         Clothing  116184.484355     2
# 3        Groceries   97751.148876     3
# 2        Furniture   29416.535511     4
# Forecasted Sales Ranking by Product for Next Year:
#          Product_Name      Quantity  Rank
# 0                  AC  15907.176418     1
# 11              Bread   8927.985147     2
# 15           Cardigan   8706.352078     3
# 36       Refrigerator   8615.518229     4
# 21                Hat   8543.108551     5
# 2             Armoire   8410.193527     6
# 35              Radio   8357.846720     7
# 38              Shirt   8351.927192     8
# 31              Mouse   8161.771524     9
# 6               Berry   8106.060060    10
# 24             Jacket   8056.729175    11
# 26           Keyboard   7962.020069    12
# 19             Gloves   7870.666979    13
# 39              Shoes   7836.546031    14
# 46              Table   7824.633359    15
# 45            T-shirt   7683.060933    16
# 27             Laptop   7602.876540    17
# 47         Television   7586.917773    18
# 10               Boot   7357.660295    19
# 4              Banana   7356.429824    20
# 5                 Bed   7299.585033    21
# 23              Heels   7295.552548    22
# 9            Bookcase   7137.219445    23
# 18                Egg   6995.665586    24
# 29               Milk   6979.164591    25
# 34           Printers   6934.249817    26
# 14              Cakes   6922.344792    27
# 22         Headphones   6880.856158    28
# 17          Condiment   6830.995173    29
# 44            Sweater   6816.670693    30
# 1               Apple   6654.548898    31
# 8   Bluetooth devices   6582.780498    32
# 7              Blazer   6517.986339    33
# 20            Granola   6459.900997    34
# 32             Orange   6409.924299    35
# 41              Socks   6397.770301    36
# 37           Shelving   6381.584236    37
# 43            Speaker   6329.729479    38
# 16              Chair   6326.203666    39
# 13            Cabinet   6282.145858    40
# 33            Ottoman   6119.609146    41
# 30             Mobile   6045.467152    42
# 48    Washing Machine   5631.674841    43
# 42               Sofa   5594.760949    44
# 40         Smartphone   5527.791056    45
# 25              Jeans   5464.754817    46
# 3             Avocado   5462.441902    47
# 12             Butter   4263.928098    48
# 28          Microwave   3777.050703    49
